# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

path= "https://www.kaggle.com/datasets/andrewmvd/fetal-health-classification"
new_path= "https://www.kaggle.com/datasets/catherinerasgaitis/mxmh-survey-results"

df= pd.read_csv("mxmh_survey_results.csv", on_bad_lines='skip')
#print(df.shape)
df.head(6)
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
# 5  8/27/2022 21:56:50  18.0                   Spotify            5.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
# ...

# %%
#nully= df.isnull()
#print(nully)

if df.isnull().values.any():
    new_df=df.fillna(0.0)
else:
    new_df=df
new_df.describe()
# Out:
#      Timestamp    Age  Primary streaming service  Hours per day  \
# 0        False  False                      False          False
# 1        False  False                      False          False
# 2        False  False                      False          False
# 3        False  False                      False          False
# 4        False  False                      False          False
# ..         ...    ...                        ...            ...
# 731      False  False                      False          False
# 732      False  False                      False          False
# 733      False  False                      False          False
# 734      False  False                      False          False
# 735      False  False                      False          False
#
#      While working  Instrumentalist  Composer  Fav genre  Exploratory  \
# 0            False            False     False      False        False
# ...

# %%
n=new_df["Age"].groupby("Fav genre")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 n=new_df["Age"].groupby("Fav genre")
#
# File c:\Users\PC\Desktop\Career\plpSoftwareEng\SEE\Practicals\pyWk7-Data Analysis\venv\lib\site-packages\pandas\core\series.py:2256, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    2253     raise TypeError("as_index=False only valid with DataFrame")
#    2254 axis = self._get_axis_number(axis)
# -> 2256 return SeriesGroupBy(
#    2257     obj=self,
#    2258     keys=by,
#    2259     axis=axis,
#    2260     level=level,
#    2261     as_index=as_index,
#    2262     sort=sort,
#    2263     group_keys=group_keys,
#    2264     observed=observed,
#    2265     dropna=dropna,
#    2266 )
#
# ...
